# %% [markdown]
# ## Advend of Code 2020 Day07

# %%
lines = []
with open("input07.txt", encoding="UTF-8") as f:
    line = f.readline().strip();
    while line:
        lines.append(line);
        line = f.readline().strip()

# %%
lines
# Out:
# ['vibrant bronze bags contain 3 dim olive bags.',
#  'shiny teal bags contain 1 posh green bag, 5 pale indigo bags, 1 mirrored purple bag.',
#  'striped aqua bags contain 5 bright orange bags.',
#  'clear chartreuse bags contain 3 dotted black bags, 2 wavy olive bags.',
#  'light lime bags contain 1 posh silver bag, 5 clear orange bags, 2 light olive bags, 3 dull maroon bags.',
#  'light olive bags contain 4 striped turquoise bags.',
#  'shiny purple bags contain 2 posh silver bags, 3 striped silver bags, 5 shiny beige bags, 2 plaid chartreuse bags.',
#  'mirrored crimson bags contain 2 faded cyan bags.',
#  'shiny turquoise bags contain 5 dull purple bags.',
#  'dim red bags contain 2 dim salmon bags, 2 faded orange bags, 5 muted aqua bags.',
#  'vibrant yellow bags contain 5 mirrored white bags, 5 vibrant blue bags, 3 mirrored lavender bags, 1 wavy cyan bag.',
#  'posh salmon bags contain 1 dull black bag, 1 striped indigo bag, 1 muted silver bag, 2 vibrant crimson bags.',
# ...

# %%
#Data structure is a list with [from, to, amount]
rules = []
for line in lines:
    #All rules end with " bags." or " bag."
    if line[:-6]
    line =
    print(line)
# Out:
# vibrant bronze bags contain 3 dim olive
# shiny teal bags contain 1 posh green bag, 5 pale indigo bags, 1 mirrored purpl
# striped aqua bags contain 5 bright orange
# clear chartreuse bags contain 3 dotted black bags, 2 wavy olive
# light lime bags contain 1 posh silver bag, 5 clear orange bags, 2 light olive bags, 3 dull maroon
# light olive bags contain 4 striped turquoise
# shiny purple bags contain 2 posh silver bags, 3 striped silver bags, 5 shiny beige bags, 2 plaid chartreuse
# mirrored crimson bags contain 2 faded cyan
# shiny turquoise bags contain 5 dull purple
# dim red bags contain 2 dim salmon bags, 2 faded orange bags, 5 muted aqua
# vibrant yellow bags contain 5 mirrored white bags, 5 vibrant blue bags, 3 mirrored lavender bags, 1 wavy cya
# posh salmon bags contain 1 dull black bag, 1 striped indigo bag, 1 muted silver bag, 2 vibrant crimson
# pale black bags contain 1 plaid cya
# dotted salmon bags contain 3 wavy brown bags, 3 pale coral bags, 1 light maroo
# ...
